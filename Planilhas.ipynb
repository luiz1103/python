# %% [markdown]
# <a href="https://colab.research.google.com/github/luiz1103/python/blob/main/Planilhas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sua experiencia trabalhando em equipe**

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQAzvjPIMYYkpUgai2zEca19DgGV-ZypKRgboOHg6ECrT1lvPpuHHvy29EyeyMTQ3SFwI8zHlKs4YEL/pub?gid=1297853556&single=true&output=csv")

# %%
dados
# Out:
#   Carimbo de data/hora Pontuação  \
# 0  08/09/2025 11:09:17     0 / 6
# 1  08/09/2025 11:12:03     0 / 6
# 2  08/09/2025 11:17:22     3 / 6
#
#   \nConte sobre um momento em que você e um colega trabalharam juntos e o que vocês aprenderam com isso.   \
# 0                            teve muitas interações
# 1              ouve muitas interações com os colegas
# 2                                    foi muito legal
#
#   \nConte sobre um momento em que você e um colega trabalharam juntos e o que vocês aprenderam com isso. .1  \
# 0                                                NaN
# 1                                                NaN
# 2                                   foi gratificante
#
#    Endereço de e-mail
# 0                 NaN
# 1                 NaN
# 2                 NaN
